# %% [markdown]
# <a href="https://colab.research.google.com/github/Ip-12345/Pickys1/blob/main/NeiralNetworks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import numpy as np
import sklearn.datasets
import matplotlib.pyplot as plt
import matplotlib
np.random.seed(0)
x, y= sklearn.datasets.make_moons(1000, noise= 0.1)
x2, y2= sklearn.datasets.make_moons(1000, noise= 0.1)
x2 =x2+2
y2 =y2+1
x= np.concatenate((x, x2))
y= np.concatenate((y, y2))
matplotlib.rcParams['figure.figsize']= (6.0,6.0)
sns.scatterplot(x=x[:, 0], y=x[:, 1], hue=y, palette="deep")
plt.title("3 Classes")
plt.show()
